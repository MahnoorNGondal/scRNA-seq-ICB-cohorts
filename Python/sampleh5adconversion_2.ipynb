# %%
import pandas as pd
import anndata
import igraph 
import leidenalg
import scanpy as sc

# %%
adata = sc.read_h5ad("/mctp/share/users/gondal/01_scHLA/02_processing/ICB_Combined/merged_tissue_cluster_update_filt_other_mal.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 355943 × 43536
#     obs: 'cell_names', 'PMID_donor_id', 'donor_id', 'pre_post', 'cell_types', 'cell_types_update', 'outcome', 'Combined_outcome', 'cell_id', 'Cancer_type', 'Cancer_type_update', 'Study_name', 'Primary_or_met', 'donor_id_pre_post', 'donor_id_outcome', 'donor_id_cell_types', 'donor_id_cell_types_pre_post', 'donor_id_pre_post_outcome', 'organism_ontology_term_id', 'tissue_ontology_term_id', 'tissue_type', 'assay_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'PMID.x', 'PMID.y', 'Sample', 'Sex', 'Treatment.or.Mode.of.Action', 'development_stage_ontology_term_id', 'suspension_type', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id'
#     var: 'features'

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 355943 × 43536
#     obs: 'cell_names', 'PMID_donor_id', 'donor_id', 'pre_post', 'cell_types', 'cell_types_update', 'outcome', 'Combined_outcome', 'cell_id', 'Cancer_type', 'Cancer_type_update', 'Study_name', 'Primary_or_met', 'donor_id_pre_post', 'donor_id_outcome', 'donor_id_cell_types', 'donor_id_cell_types_pre_post', 'donor_id_pre_post_outcome', 'organism_ontology_term_id', 'tissue_ontology_term_id', 'tissue_type', 'assay_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'PMID.x', 'PMID.y', 'Sample', 'Sex', 'Treatment.or.Mode.of.Action', 'development_stage_ontology_term_id', 'suspension_type', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id'
#     var: 'features'

# %%
# Perform PCA
sc.pp.pca(adata, n_comps=20)

# Compute neighbors
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=20)

# Perform UMAP
sc.tl.umap(adata)

# %%
# Perform clustering
sc.tl.leiden(adata, resolution=0.5)

# Visualize the clusters using UMAP
sc.pl.umap(adata, color=['leiden'])

# %%
sc.pl.umap(adata, color='Cancer_type')  # Replace 'cell_type' with your metadata column

# %%
sc.pl.umap(adata, color='cell_types_update')  # Replace 'cell_type' with your metadata column

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 355943 × 43536
#     obs: 'cell_names', 'PMID_donor_id', 'donor_id', 'pre_post', 'cell_types', 'cell_types_update', 'outcome', 'Combined_outcome', 'cell_id', 'Cancer_type', 'Cancer_type_update', 'Study_name', 'Primary_or_met', 'donor_id_pre_post', 'donor_id_outcome', 'donor_id_cell_types', 'donor_id_cell_types_pre_post', 'donor_id_pre_post_outcome', 'organism_ontology_term_id', 'tissue_ontology_term_id', 'tissue_type', 'assay_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'PMID.x', 'PMID.y', 'Sample', 'Sex', 'Treatment.or.Mode.of.Action', 'development_stage_ontology_term_id', 'suspension_type', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'leiden'
#     var: 'features'
#     uns: 'pca', 'neighbors', 'umap', 'leiden', 'leiden_colors', 'Cancer_type_colors', 'cell_types_update_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
print(adata.raw.var.columns)
# Out:
# Index(['_index'], dtype='object')

# %%
adata.raw.var.rename(columns={'_index': 'index'}, inplace=True)  # Change '_index' to 'index' or any other valid name

# %%
adata.write_h5ad("/mctp/share/users/gondal/01_scHLA/03_output/ICI_Combined_revised/version_07_10_08_24/processed_data_uc.h5ad")

# %%
adata.write_h5ad("/mctp/share/users/gondal/01_scHLA/03_output/ICI_Combined_revised/version_07_10_08_24/processed_data.h5ad", compression="gzip")

# %%
adata = sc.read_h5ad('/mctp/share/users/gondal/01_scHLA/03_output/ICI_Combined_revised/version_07_10_08_24/processed_data_uc.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 355943 × 43536
#     obs: 'cell_names', 'PMID_donor_id', 'donor_id', 'pre_post', 'cell_types', 'cell_types_update', 'outcome', 'Combined_outcome', 'cell_id', 'Cancer_type', 'Cancer_type_update', 'Study_name', 'Primary_or_met', 'donor_id_pre_post', 'donor_id_outcome', 'donor_id_cell_types', 'donor_id_cell_types_pre_post', 'donor_id_pre_post_outcome', 'organism_ontology_term_id', 'tissue_ontology_term_id', 'tissue_type', 'assay_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'PMID.x', 'PMID.y', 'Sample', 'Sex', 'Treatment.or.Mode.of.Action', 'development_stage_ontology_term_id', 'suspension_type', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'leiden'
#     var: 'features'
#     uns: 'Cancer_type_colors', 'cell_types_update_colors', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                                                                                            cell_names  \
# M21_3p2_Lym_A01_S1                                                                 M21_3p2_Lym_A01_S1
# M21_3p2_Lym_A02_S2                                                                 M21_3p2_Lym_A02_S2
# M21_3p2_Lym_A03_S3                                                                 M21_3p2_Lym_A03_S3
# M21_3p2_Lym_A04_S4                                                                 M21_3p2_Lym_A04_S4
# M21_3p2_Lym_A05_S5                                                                 M21_3p2_Lym_A05_S5
# ...                                                                                               ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...  BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCA...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...  BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCC...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...  BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCG...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...  BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGG...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...  BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTC...
#
#                                                         PMID_donor_id  \
# M21_3p2_Lym_A01_S1                                  35706413gggMEL021
# M21_3p2_Lym_A02_S2                                  35706413gggMEL021
# M21_3p2_Lym_A03_S3                                  35706413gggMEL021
# M21_3p2_Lym_A04_S4                                  35706413gggMEL021
# M21_3p2_Lym_A05_S5                                  35706413gggMEL021
# ...                                                               ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...   31359002gggsu008
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...   31359002gggsu008
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...   31359002gggsu008
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...   31359002gggsu008
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...   31359002gggsu008
#
#                                                    donor_id pre_post  \
# M21_3p2_Lym_A01_S1                                   MEL021     Post
# M21_3p2_Lym_A02_S2                                   MEL021     Post
# M21_3p2_Lym_A03_S3                                   MEL021     Post
# M21_3p2_Lym_A04_S4                                   MEL021     Post
# M21_3p2_Lym_A05_S5                                   MEL021     Post
# ...                                                     ...      ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...    su008     Post
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...    su008     Post
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...    su008     Post
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...    su008     Post
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...    su008     Post
#
#                                                    cell_types  \
# M21_3p2_Lym_A01_S1                                     T Cell
# M21_3p2_Lym_A02_S2                                     T Cell
# M21_3p2_Lym_A03_S3                                     T Cell
# M21_3p2_Lym_A04_S4                                     T Cell
# M21_3p2_Lym_A05_S5                                     T Cell
# ...                                                       ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...         NA
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...         NA
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...         NA
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...         NA
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...         NA
#
#                                                    cell_types_update outcome  \
# M21_3p2_Lym_A01_S1                                            T_cell      PR
# M21_3p2_Lym_A02_S2                                            T_cell      PR
# M21_3p2_Lym_A03_S3                                            T_cell      PR
# M21_3p2_Lym_A04_S4                                            T_cell      PR
# M21_3p2_Lym_A05_S5                                            T_cell      PR
# ...                                                              ...     ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...         Malignant      No
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...         Malignant      No
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...         Malignant      No
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...         Malignant      No
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...         Malignant      No
#
#                                                    Combined_outcome  \
# M21_3p2_Lym_A01_S1                                       Favourable
# M21_3p2_Lym_A02_S2                                       Favourable
# M21_3p2_Lym_A03_S3                                       Favourable
# M21_3p2_Lym_A04_S4                                       Favourable
# M21_3p2_Lym_A05_S5                                       Favourable
# ...                                                             ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...     Unfavourable
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...     Unfavourable
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...     Unfavourable
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...     Unfavourable
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...     Unfavourable
#
#                                                                                        cell_id  \
# M21_3p2_Lym_A01_S1                                                          M21_3p2_Lym_A01_S1
# M21_3p2_Lym_A02_S2                                                          M21_3p2_Lym_A02_S2
# M21_3p2_Lym_A03_S3                                                          M21_3p2_Lym_A03_S3
# M21_3p2_Lym_A04_S4                                                          M21_3p2_Lym_A04_S4
# M21_3p2_Lym_A05_S5                                                          M21_3p2_Lym_A05_S5
# ...                                                                                        ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...  bcc.su008.post.tumor.cd45_TCAGCTCAGGTGATAT
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...  bcc.su008.post.tumor.cd45_TCCACACGTGTCCTCT
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...  bcc.su008.post.tumor.cd45_TCGGGACTCGGAGGTA
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...  bcc.su008.post.tumor.cd45_TGGCCAGCAATACGCT
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...  bcc.su008.post.tumor.cd45_TTCTTAGGTCTCACCT
#
#                                                                           Cancer_type  \
# M21_3p2_Lym_A01_S1                                  Melanoma_derived_brain_metastases
# M21_3p2_Lym_A02_S2                                  Melanoma_derived_brain_metastases
# M21_3p2_Lym_A03_S3                                  Melanoma_derived_brain_metastases
# M21_3p2_Lym_A04_S4                                  Melanoma_derived_brain_metastases
# M21_3p2_Lym_A05_S5                                  Melanoma_derived_brain_metastases
# ...                                                                               ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...               Basal_Cell_Carcinoma
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...               Basal_Cell_Carcinoma
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...               Basal_Cell_Carcinoma
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...               Basal_Cell_Carcinoma
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...               Basal_Cell_Carcinoma
#
#                                                     ...    PMID.x    PMID.y  \
# M21_3p2_Lym_A01_S1                                  ...  35706413  35706413
# M21_3p2_Lym_A02_S2                                  ...  35706413  35706413
# M21_3p2_Lym_A03_S3                                  ...  35706413  35706413
# M21_3p2_Lym_A04_S4                                  ...  35706413  35706413
# M21_3p2_Lym_A05_S5                                  ...  35706413  35706413
# ...                                                 ...       ...       ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...  ...  31359002  31359002
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...  ...  31359002  31359002
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...  ...  31359002  31359002
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...  ...  31359002  31359002
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...  ...  31359002  31359002
#
#                                                     Sample      Sex  \
# M21_3p2_Lym_A01_S1                                  MEL021        M
# M21_3p2_Lym_A02_S2                                  MEL021        M
# M21_3p2_Lym_A03_S3                                  MEL021        M
# M21_3p2_Lym_A04_S4                                  MEL021        M
# M21_3p2_Lym_A05_S5                                  MEL021        M
# ...                                                    ...      ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...   su008  Unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...   su008  Unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...   su008  Unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...   su008  Unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...   su008  Unknown
#
#                                                    Treatment.or.Mode.of.Action  \
# M21_3p2_Lym_A01_S1                                          interferon Alfa-2b
# M21_3p2_Lym_A02_S2                                          interferon Alfa-2b
# M21_3p2_Lym_A03_S3                                          interferon Alfa-2b
# M21_3p2_Lym_A04_S4                                          interferon Alfa-2b
# M21_3p2_Lym_A05_S5                                          interferon Alfa-2b
# ...                                                                        ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...               Pembrolizumab
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...               Pembrolizumab
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...               Pembrolizumab
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...               Pembrolizumab
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...               Pembrolizumab
#
#                                                    development_stage_ontology_term_id  \
# M21_3p2_Lym_A01_S1                                                            unknown
# M21_3p2_Lym_A02_S2                                                            unknown
# M21_3p2_Lym_A03_S3                                                            unknown
# M21_3p2_Lym_A04_S4                                                            unknown
# M21_3p2_Lym_A05_S5                                                            unknown
# ...                                                                               ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...                            unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...                            unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...                            unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...                            unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...                            unknown
#
#                                                    suspension_type  \
# M21_3p2_Lym_A01_S1                                            cell
# M21_3p2_Lym_A02_S2                                            cell
# M21_3p2_Lym_A03_S3                                            cell
# M21_3p2_Lym_A04_S4                                            cell
# M21_3p2_Lym_A05_S5                                            cell
# ...                                                            ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...            cell
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...            cell
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...            cell
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...            cell
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...            cell
#
#                                                    sex_ontology_term_id  \
# M21_3p2_Lym_A01_S1                                         PATO:0000384
# M21_3p2_Lym_A02_S2                                         PATO:0000384
# M21_3p2_Lym_A03_S3                                         PATO:0000384
# M21_3p2_Lym_A04_S4                                         PATO:0000384
# M21_3p2_Lym_A05_S5                                         PATO:0000384
# ...                                                                 ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...              unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...              unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...              unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...              unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...              unknown
#
#                                                    self_reported_ethnicity_ontology_term_id  \
# M21_3p2_Lym_A01_S1                                                                  unknown
# M21_3p2_Lym_A02_S2                                                                  unknown
# M21_3p2_Lym_A03_S3                                                                  unknown
# M21_3p2_Lym_A04_S4                                                                  unknown
# M21_3p2_Lym_A05_S5                                                                  unknown
# ...                                                                                     ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...                                  unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...                                  unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...                                  unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...                                  unknown
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...                                  unknown
#
#                                                    leiden
# M21_3p2_Lym_A01_S1                                     18
# M21_3p2_Lym_A02_S2                                     18
# M21_3p2_Lym_A03_S3                                     18
# M21_3p2_Lym_A04_S4                                     18
# M21_3p2_Lym_A05_S5                                     18
# ...                                                   ...
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCAG...     28
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCCA...     28
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCGG...     33
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGGC...     28
# BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTCT...     28
#
# [355943 rows x 34 columns]

# %%
# Extract UMAP embeddings from obsm
umap_coords = adata.obsm['X_umap']

# Extract cell IDs from obs
cell_ids = adata.obs['cell_names']

# Combine UMAP coordinates and cell IDs into a DataFrame
umap_df = pd.DataFrame(umap_coords, columns=['UMAP_1', 'UMAP_2'])
umap_df['cell_id'] = cell_ids.values

# Save the DataFrame to a CSV file
umap_df.to_csv('/mctp/share/users/gondal/01_scHLA/03_output/ICI_Combined_revised/version_07_10_08_24/umap_coordinates.csv', index=False)

# %%
umap_df
# Out:
#           UMAP_1    UMAP_2                                            cell_id
# 0      -2.719466  1.093943                                 M21_3p2_Lym_A01_S1
# 1      -2.695960  0.697825                                 M21_3p2_Lym_A02_S2
# 2      -2.794993  0.449751                                 M21_3p2_Lym_A03_S3
# 3      -3.276160  0.395312                                 M21_3p2_Lym_A04_S4
# 4      -3.078309  0.398335                                 M21_3p2_Lym_A05_S5
# ...          ...       ...                                                ...
# 355938 -0.310076  4.679035  BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCA...
# 355939 -0.308208  4.496641  BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCC...
# 355940  8.352202  2.489020  BCC_previous_BCC_bcc.su008.post.tumor.cd45_TCG...
# 355941 -0.579225  4.649842  BCC_previous_BCC_bcc.su008.post.tumor.cd45_TGG...
# 355942 -0.499282  4.437880  BCC_previous_BCC_bcc.su008.post.tumor.cd45_TTC...
#
# [355943 rows x 3 columns]
